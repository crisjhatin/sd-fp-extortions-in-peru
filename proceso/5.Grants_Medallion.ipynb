# %% [markdown]
# ##Grants

# %%
# %sql
-- Otorgar acceso a tabla circuits
GRANT SELECT ON TABLE catalog_au.bronze.circuits TO `hayley_0203@outlook.com`;

# %%
# %sql
-- Otorgar acceso a catalogo catalog_au
GRANT USE CATALOG ON CATALOG catalog_au TO `hayley_0203@outlook.com`;

# %%
# %sql
-- Otorgar acceso de USE SCHEMA a esquema bronze
GRANT USE SCHEMA ON SCHEMA catalog_au.bronze TO `hayley_0203@outlook.com`;

--GRANT USE SCHEMA ON SCHEMA catalog_au.bronze TO `Desarrolladores`;
--GRANT CREATE ON SCHEMA catalog_au.bronze TO `Desarrolladores`;

# %%
# %sql
-- Otorgar acceso de CREATE TABLE a esquema bronze
GRANT CREATE TABLE ON SCHEMA catalog_au.bronze TO `hayley_0203@outlook.com`;

# %%
# %sql
-- Otorgar acceso de select a tablas productos y clientes_validos
--GRANT SELECT ON TABLE catalog_dev.bronze.productos TO `Admins_Smart`;
--GRANT SELECT ON TABLE catalog_dev.silver.clientes_validos TO `Analistas`;

-- GRANT CREATE ON CATALOG demo_catalog TO `Dvelopers`;
-- GRANT SELECT ON CATALOG demo_catalog TO `Dvelopers`;
-- GRANT ALL PRIVILEGES ON CATALOG demo_catalog TO `Admins`;

# %%
# %sql
-- Mostrar permisos en tabla circuits
SHOW GRANTS ON TABLE catalog_au.bronze.circuits;

# %%
# %sql
-- Mostrar permisos en esquema bronze
SHOW GRANTS ON SCHEMA catalog_au.bronze;

# %%
# %sql
-- Mostrar permisos en catalogo
SHOW GRANTS ON CATALOG catalog_au;

# %%
# %sql
-- Eliminar permiso de USE SCHEMA a usuario Hayley.
REVOKE USE SCHEMA ON SCHEMA catalog_au.bronze FROM `hayley_0203@outlook.com`;

# %%
# %sql
SHOW GRANTS ON SCHEMA catalog_au.bronze;

# %%
# %sql
SHOW EXTERNAL LOCATIONS

# %%
# %sql
SHOW GRANTS ON EXTERNAL LOCATION `exlt-raw`

# %%
# %sql
-- Otorgar permisos de lectura en contenedor raw.
GRANT READ FILES
ON EXTERNAL LOCATION `exlt-raw`
TO `hayley_0203@outlook.com`;

# %%
# %sql
-- Otorgar permisos de escritura en contenedor bronze
GRANT WRITE FILES
ON EXTERNAL LOCATION `exlt-bronze`
TO `hayley_0203@outlook.com`;

# %%
# %sql
-- Otorgar permisos de lectura y escritura en contenedor bronze
GRANT ALL PRIVILEGES
ON EXTERNAL LOCATION `exlt-bronze`
TO `hayley_0203@outlook.com`;

# %%
# %sql
-- Crear grupo de usuarios
CREATE GROUP `data_engineers`;

# %%
# %sql
--ALTER GROUP `data_engineers`
--ADD USER `ahuaccachi28@gmail.com`;

# %%
# %sql
SHOW USERS;
